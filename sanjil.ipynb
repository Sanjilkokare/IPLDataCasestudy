# %%
#import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read ipl.csv file and print first 5 records
df = pd.read_csv("ipl data.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#check total number of columns,entries note down your findings
df.info()
#Findings:-
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
# find null values 
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
#drop umpire3 column as it contains more than 75% of null values


df.drop(columns="umpire3",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              636 non-null    int64
#  1   season          636 non-null    int64
#  2   date            636 non-null    object
#  3   team1           636 non-null    object
#  4   team2           636 non-null    object
#  5   toss_winner     636 non-null    object
#  6   toss_decision   636 non-null    object
#  7   result          636 non-null    object
#  8   dl_applied      636 non-null    int64
#  9   win_by_runs     636 non-null    int64
#  10  win_by_wickets  636 non-null    int64
#  11  venue           636 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 59.8+ KB

# %%
#which city hosted most number of matches?
#draw bar plot and write down your insights

df.groupby("city")["city"].value_counts().sort_values(ascending=False).head()
# Out:
# city       city
# Mumbai     Mumbai       85
# Bangalore  Bangalore    66
# Kolkata    Kolkata      61
# Delhi      Delhi        60
# Hyderabad  Hyderabad    49
# Name: city, dtype: int64

# %%
#find all venue of mumbai city

c = df.groupby("city").get_group("Mumbai")["venue"].value_counts()
c
# Out:
# Wankhede Stadium              57
# Dr DY Patil Sports Academy    17
# Brabourne Stadium             11
# Name: venue, dtype: int64

# %%
df[df["city"]=="Mumbai",]
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..   ...     ...     ...         ...                          ...
# 572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# 6             Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
#now compare in which venue of mumbai most number of matches played (draw bar plot and  write down insights)
b = df.groupby("city").get_group("Mumbai")["venue"].max()
c= df.groupby("venue").get_group(b)["venue"].value_counts()
c
# Out:
# Wankhede Stadium    57
# Name: venue, dtype: int64

# %%
plt.figure(figsize=(3,6))
sns.barplot(data=c,label="venue")

plt.legend()
plt.show()

# %%
#what is the preferred choice after winning a toss in mumbai

a = df.groupby("city").get_group("Mumbai")["toss_decision"].value_counts()
a
# Out:
# field    51
# bat      34
# Name: toss_decision, dtype: int64

# %%
#graphical representation of above question

a.plot.pie(autopct = "%1.0f%%")
plt.title("decision after the toss")
plt.show()

# %%
#which team won most number of toss :-Mumbai Indians

df.groupby("toss_winner").get_group("Mumbai Indians")["toss_winner"].value_counts()
# Out:
# Mumbai Indians    85
# Name: toss_winner, dtype: int64

# %%
#show graphical representation of above question

df.groupby("toss_winner").get_group("Mumbai Indians")["toss_winner"].value_counts().plot.bar()
plt.show()

# %%
#find what mumbai indians preferred after winning a toss?

df.groupby("team1").get_group("Mumbai Indians")["toss_decision"].value_counts()
# Out:
# field    42
# bat      40
# Name: toss_decision, dtype: int64

# %%
#head to head winning count of Mumbai Indians vs Chennai Super Kings
df[(df["team1"]=="Mumbai Indians") | (df["team2"]=="Chennai Super King")]
# Out:
#       id  season           city        date           team1  \
# 1      2    2017           Pune  2017-04-06  Mumbai Indians
# 23    24    2017         Mumbai  2017-04-22  Mumbai Indians
# 43    44    2017          Delhi  2017-05-06  Mumbai Indians
# 46    47    2017      Hyderabad  2017-05-08  Mumbai Indians
# 52    53    2017        Kolkata  2017-05-13  Mumbai Indians
# ..   ...     ...            ...         ...             ...
# 587  588    2016      Hyderabad  2016-04-18  Mumbai Indians
# 596  597    2016     Chandigarh  2016-04-25  Mumbai Indians
# 618  619    2016  Visakhapatnam  2016-05-13  Mumbai Indians
# 622  623    2016  Visakhapatnam  2016-05-15  Mumbai Indians
# 629  630    2016         Kanpur  2016-05-21  Mumbai Indians
#
#                       team2             toss_winner toss_decision  result  \
# 1    Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 23         Delhi Daredevils        Delhi Daredevils         field  normal
# ...

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#Which team won most of the matches in mumbai?

df.groupby("winner").get_group("Mumbai Indians")["city"].value_counts()
# Out:
# Mumbai            45
# Kolkata            9
# Bangalore          8
# Hyderabad          5
# Chandigarh         4
# Pune               3
# Delhi              3
# Chennai            3
# Jaipur             2
# Visakhapatnam      2
# Port Elizabeth     2
# Centurion          1
# East London        1
# Cape Town          1
# Rajkot             1
# Indore             1
# Ahmedabad          1
# Name: city, dtype: int64

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#how many times each team won the toss and won the match in mumbai

#df.loc[df["city"]=="Mumbai"][("winner")].value_counts()
# df.groupby("city").get_group("Mumbai")["toss_winner"].value_counts()
df[(df['winner']==df['toss_winner']) & (df['city']=='Mumbai')]
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 71    72    2008  Mumbai  2008-04-27               Mumbai Indians
# 85    86    2008  Mumbai  2008-05-07             Rajasthan Royals
# 95    96    2008  Mumbai  2008-05-14          Chennai Super Kings
# 98    99    2008  Mumbai  2008-05-16        Kolkata Knight Riders
# 116  117    2008  Mumbai  2008-06-01          Chennai Super Kings
# 175  176    2010  Mumbai  2010-03-13               Mumbai Indians
# 193  194    2010  Mumbai  2010-03-25          Chennai Super Kings
# 200  201    2010  Mumbai  2010-03-30              Kings XI Punjab
# 206  207    2010  Mumbai  2010-04-03               Mumbai Indians
# 220  221    2010  Mumbai  2010-04-13               Mumbai Indians
# ...

# %%
#which venue hosted most number of matches
df["venue"].value_counts().max()
# Out:
# 66

# %%
#find how many matches chennai super kings played at M Chinnaswamy stadium?
#df.groupby("venue").get_group("M Chinnaswamy Stadium")["team1"].value_counts()

df.loc[df["venue"]=="M Chinnaswamy Stadium"][df["team1"]=="Chennai Super Kings"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12772\1690838510.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[df["venue"]=="M Chinnaswamy Stadium"][df["team1"]=="Chennai Super Kings"]
#       id  season       city        date                team1  \
# 73    74    2008  Bangalore  2008-04-28  Chennai Super Kings
# 301  302    2011  Bangalore  2011-05-22  Chennai Super Kings
# 378  379    2012  Bangalore  2012-05-23  Chennai Super Kings
# 537  538    2015  Bangalore  2015-04-22  Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 73   Royal Challengers Bangalore          Chennai Super Kings           bat
# 301  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 378               Mumbai Indians               Mumbai Indians         field
# 537  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
# ...

# %%
#who won most matches at M Chinnaswamy stadium?--Royal Challengers Bangalore
df.groupby("venue").get_group("M Chinnaswamy Stadium")["team1"].value_counts()
# Out:
# Royal Challengers Bangalore    33
# Kolkata Knight Riders           7
# Kings XI Punjab                 4
# Sunrisers Hyderabad             4
# Chennai Super Kings             4
# Rajasthan Royals                3
# Delhi Daredevils                3
# Mumbai Indians                  2
# Rising Pune Supergiant          1
# Kochi Tuskers Kerala            1
# Pune Warriors                   1
# Deccan Chargers                 1
# Rising Pune Supergiants         1
# Gujarat Lions                   1
# Name: team1, dtype: int64

# %%
#matches played in each year
df.loc[df["season"]==2017].count()
# Out:
# id                 59
# season             59
# city               59
# date               59
# team1              59
# team2              59
# toss_winner        59
# toss_decision      59
# result             59
# dl_applied         59
# winner             59
# win_by_runs        59
# win_by_wickets     59
# player_of_match    59
# venue              59
# umpire1            58
# umpire2            58
# umpire3             0
# dtype: int64

# %%
#which city hosted most number of matches in 2013 

df.loc[df["season"]==2013]["city"].value_counts()
# Out:
# Kolkata       8
# Bangalore     8
# Hyderabad     8
# Delhi         8
# Chennai       8
# Pune          8
# Jaipur        8
# Mumbai        8
# Chandigarh    6
# Dharamsala    2
# Raipur        2
# Ranchi        2
# Name: city, dtype: int64

# %%
#lets analyse ipl season held in 2013
#extract all the details of 2013 season
#here we will create yearwise groups (hint: use groupby() function)
df.groupby("season").get_group(2013).count()
# Out:
# id                 76
# season             76
# city               76
# date               76
# team1              76
# team2              76
# toss_winner        76
# toss_decision      76
# result             76
# dl_applied         76
# winner             76
# win_by_runs        76
# win_by_wickets     76
# player_of_match    76
# venue              76
# umpire1            76
# umpire2            76
# dtype: int64

# %%
df.groupby("season").get_group(2013).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 381 to 456
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               76 non-null     int64
#  1   season           76 non-null     int64
#  2   city             76 non-null     object
#  3   date             76 non-null     object
#  4   team1            76 non-null     object
#  5   team2            76 non-null     object
#  6   toss_winner      76 non-null     object
#  7   toss_decision    76 non-null     object
#  8   result           76 non-null     object
#  9   dl_applied       76 non-null     int64
#  10  winner           76 non-null     object
#  11  win_by_runs      76 non-null     int64
#  12  win_by_wickets   76 non-null     int64
#  13  player_of_match  76 non-null     object
#  14  venue            76 non-null     object
#  15  umpire1          76 non-null     object
#  16  umpire2          76 non-null     object
# ...
